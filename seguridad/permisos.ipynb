# %%
# %sql
GRANT ALL PRIVILEGES ON CATALOG catalog_project TO `DataEnginers`;
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_project.bronze to `DataEnginers`;
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_project.silver to `DataEnginers`;
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_project.golden to `DataEnginers`;

# %%
# %sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` to `DataEnginers`;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.bronze.customer_detail;
DROP TABLE IF EXISTS catalog_project.bronze.ecommerce_sales;
DROP TABLE IF EXISTS catalog_project.bronze.product_detail;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.silver.ecommerce_sales;

# %%
# %sql
DROP TABLE IF EXISTS catalog_project.golden.ingresos_por_categoria;
DROP TABLE IF EXISTS catalog_project.golden.ingresos_por_genero;
DROP TABLE IF EXISTS catalog_project.golden.ingresos_por_suscripcion;
DROP TABLE IF EXISTS catalog_project.golden.ingresos_por_estado;
